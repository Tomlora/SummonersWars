# %%
import pandas as pd
import numpy as np
import json
import plotly.express as px
import ast

# fix plotly express et Visual Studio Code
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
def extraire_variables_imbriquees(df, colonne):
    df[colonne] = [ast.literal_eval(str(item)) for index, item in df[colonne].iteritems()]

    df = pd.concat([df.drop([colonne], axis=1), df[colonne].apply(pd.Series)], axis=1)
    return df

def export_excel(data, data_short):
        writer = pd.ExcelWriter("test.xlsx")
        data.to_excel(writer, startrow=0, sheet_name='Data_complete', index=True)
        data_short.to_excel(writer, startrow=0, sheet_name='Data_short', index=True)
        
        workbook = writer.book
        worksheet1 = writer.sheets['Data_complete']
        worksheet2 = writer.sheets['Data_short']

        # Gestion de la taille des colonnes

        cell_format = workbook.add_format({'valign':'vcenter', 'align': 'center'})
        cell_format.set_text_wrap()
        for i, col in enumerate(data.columns):
                worksheet1.set_column(i, i+1, 20, cell_format) # colonne, colonne, len_colonne, format colonne
        for i, col in enumerate(data_short.columns):
                worksheet2.set_column(i, i+1, 20, cell_format) # colonne, colonne, len_colonne, format colonne

        writer.save()

# %% [markdown]
# # Import data

# %%
f = open('Tømløra-158491.json', encoding="utf8")

# %%
# On charge le json
data_json = json.load(f)

# %%
data_json['runes'][0]
# Out:
# {'rune_id': 14111400433,
#  'wizard_id': 158491,
#  'occupied_type': 2,
#  'occupied_id': 0,
#  'slot_no': 2,
#  'rank': 5,
#  'class': 6,
#  'set_id': 1,
#  'upgrade_limit': 15,
#  'upgrade_curr': 15,
#  'base_value': 443800,
#  'sell_value': 33181,
#  'pri_eff': [8, 42],
#  'prefix_eff': [5, 13],
#  'sec_eff': [[6, 11, 0, 6], [9, 5, 0, 0], [10, 18, 0, 0], [4, 5, 1, 7]],
#  'extra': 4}

# %%
player_runes = {}

# Rune pas équipé
for rune in data_json['runes']:
    first_sub = 0
    first_sub_value = 0
    first_sub_grinded_value = 0
    second_sub = 0
    second_sub_value = 0
    second_sub_grinded_value = 0
    third_sub = 0
    third_sub_value = 0
    third_sub_grinded_value = 0
    fourth_sub = 0
    fourth_sub_value = 0
    fourth_sub_grinded_value = 0

    rune_id = rune['rune_id']
    rune_set = rune['set_id']
    rune_slot = rune['slot_no']
    rune_equiped = rune['occupied_id']
    stars = rune['class']
    level = rune['upgrade_curr']
    efficiency = 0
    max_efficiency = 0
    max_efficiency_reachable = 0
    gain = 0
    main_type = rune['pri_eff'][0]
    main_value = rune['pri_eff'][1]
    innate_type = rune['prefix_eff'][0]
    innate_value = rune['prefix_eff'][1]

    if level > 2:
        first_sub = rune['sec_eff'][0][0]
        first_sub_value = rune['sec_eff'][0][1]
        first_gemme_bool = rune['sec_eff'][0][2]
        first_sub_grinded_value = rune['sec_eff'][0][3]
    if level > 5:
        second_sub = rune['sec_eff'][1][0]
        second_sub_value = rune['sec_eff'][1][1]
        second_gemme_bool = rune['sec_eff'][1][2]
        second_sub_grinded_value = rune['sec_eff'][1][3]
    if level > 8:
        third_sub = rune['sec_eff'][2][0]
        third_sub_value = rune['sec_eff'][2][1]
        third_gemme_bool = rune['sec_eff'][2][2]
        third_sub_grinded_value = rune['sec_eff'][2][3]
    if level > 11:
        fourth_sub = rune['sec_eff'][3][0]
        fourth_sub_value = rune['sec_eff'][3][1]
        fourth_gemme_bool = rune['sec_eff'][3][2]
        fourth_sub_grinded_value = rune['sec_eff'][3][3]
    player_runes[rune_id] =  [rune_set, rune_slot, rune_equiped, stars, level, efficiency, max_efficiency,
                              max_efficiency_reachable, gain, main_type, main_value, innate_type, innate_value,
                              first_sub, first_sub_value, first_gemme_bool,  first_sub_grinded_value, second_sub, second_sub_value, second_gemme_bool,
                              second_sub_grinded_value, third_sub, third_sub_value, third_gemme_bool, third_sub_grinded_value, fourth_sub,
                              fourth_sub_value, fourth_gemme_bool, fourth_sub_grinded_value]

# Rune équipée
for unit in data_json['unit_list']:
    for stat in unit:
        if stat == "runes":
            for rune in unit[stat]:
                first_sub = 0
                first_sub_value = 0
                first_sub_grinded_value = 0
                second_sub = 0
                second_sub_value = 0
                second_sub_grinded_value = 0
                third_sub = 0
                third_sub_value = 0
                third_sub_grinded_value = 0
                fourth_sub = 0
                fourth_sub_value = 0
                fourth_sub_grinded_value = 0

                rune_id = rune['rune_id']
                rune_set = rune['set_id']
                rune_slot = rune['slot_no']
                rune_equiped = rune['occupied_id']
                stars = rune['class']
                level = rune['upgrade_curr']
                efficiency = 0
                max_efficiency = 0
                max_efficiency_reachable = 0
                gain = 0
                main_type = rune['pri_eff'][0]
                main_value = rune['pri_eff'][1]
                innate_type = rune['prefix_eff'][0]
                innate_value = rune['prefix_eff'][1]
                # rank = rune['extra']
                if level > 2:
                    first_sub = rune['sec_eff'][0][0]
                    first_sub_value = rune['sec_eff'][0][1]
                    first_gemme_bool = rune['sec_eff'][0][2]
                    first_sub_grinded_value = rune['sec_eff'][0][3]
                if level > 5:
                    second_sub = rune['sec_eff'][1][0]
                    second_sub_value = rune['sec_eff'][1][1]
                    second_gemme_bool = rune['sec_eff'][1][2]
                    second_sub_grinded_value = rune['sec_eff'][1][3]
                if level > 8:
                    third_sub = rune['sec_eff'][2][0]
                    third_sub_value = rune['sec_eff'][2][1]
                    third_gemme_bool = rune['sec_eff'][2][2]
                    third_sub_grinded_value = rune['sec_eff'][2][3]
                if level > 11:
                    fourth_sub = rune['sec_eff'][3][0]
                    fourth_sub_value = rune['sec_eff'][3][1]
                    fourth_gemme_bool = rune['sec_eff'][3][2]
                    fourth_sub_grinded_value = rune['sec_eff'][3][3]
                player_runes[rune_id] =  [rune_set, rune_slot, rune_equiped, stars, level, efficiency, max_efficiency,
                              max_efficiency_reachable, gain, main_type, main_value, innate_type, innate_value,
                              first_sub, first_sub_value, first_gemme_bool, first_sub_grinded_value, second_sub, second_sub_value, second_gemme_bool,
                              second_sub_grinded_value, third_sub, third_sub_value, third_gemme_bool, third_sub_grinded_value, fourth_sub,
                              fourth_sub_value, fourth_gemme_bool, fourth_sub_grinded_value]

# %%
data = pd.DataFrame.from_dict(player_runes, orient="index", columns=['rune_set', 'rune_slot', 'rune_equiped', 'stars', 'level', 'efficiency', 'max_efficiency', 'max_efficiency_reachable', 'gain', 'main_type', 'main_value', 'innate_type',
                                                                     'innate_value',
                              'first_sub', 'first_sub_value', 'first_gemme_bool', 'first_sub_grinded_value', 'second_sub', 'second_sub_value', 'second_gemme_bool',
                              'second_sub_grinded_value', 'third_sub', 'third_sub_value', 'third_gemme_bool', 'third_sub_grinded_value', 'fourth_sub',
                              'fourth_sub_value', 'fourth_gemme_bool', 'fourth_sub_grinded_value'])
data
# Out:
#              rune_set  rune_slot  rune_equiped  stars  level  efficiency  \
# 14111400433         1          2             0      6     15           0
# 16026596194         1          2             0      6     15           0
# 28386629404         1          2             0      6     15           0
# 29119359657         1          2             0      6     15           0
# 29012261537         1          3             0      6     15           0
# ...               ...        ...           ...    ...    ...         ...
# 20430727030        19          2   12336450247      4     15           0
# 18234665295        15          3   12336450247      3      0           0
# 18272114995        19          4   12336450247      5      0           0
# 18272149229        19          5   12336450247      5      0           0
# 18271978338        19          6   12336450247      5      0           0
#
#              max_efficiency  max_efficiency_reachable  gain  main_type  ...  \
# 14111400433               0                         0     0          8  ...
# 16026596194               0                         0     0          8  ...
# 28386629404               0                         0     0          8  ...
# 29119359657               0                         0     0          8  ...
# 29012261537               0                         0     0          5  ...
# ...                     ...                       ...   ...        ...  ...
# 20430727030               0                         0     0          8  ...
# 18234665295               0                         0     0          5  ...
# 18272114995               0                         0     0         10  ...
# 18272149229               0                         0     0          1  ...
# 18271978338               0                         0     0          3  ...
#
#              second_gemme_bool  second_sub_grinded_value  third_sub  \
# 14111400433                  0                         0         10
# 16026596194                  0                         0         11
# 28386629404                  0                         5          6
# 29119359657                  0                         6          4
# 29012261537                  0                         3          6
# ...                        ...                       ...        ...
# 20430727030                  0                         0          4
# 18234665295                  0                         0          0
# 18272114995                  0                         0          0
# 18272149229                  0                         0          0
# 18271978338                  0                         0          0
#
#              third_sub_value  third_gemme_bool  third_sub_grinded_value  \
# 14111400433               18                 0                        0
# 16026596194               10                 1                        0
# 28386629404                8                 1                        6
# 29119359657               12                 0                        6
# 29012261537                6                 0                        6
# ...                      ...               ...                      ...
# 20430727030                5                 0                        0
# 18234665295                0                 0                        0
# 18272114995                0                 0                        0
# 18272149229                0                 0                        0
# 18271978338                0                 0                        0
#
#              fourth_sub  fourth_sub_value  fourth_gemme_bool  \
# 14111400433           4                 5                  1
# 16026596194           6                 6                  0
# 28386629404          11                13                  0
# 29119359657           9                 6                  0
# 29012261537          11                 7                  0
# ...                 ...               ...                ...
# 20430727030          10                 2                  0
# 18234665295           0                 0                  0
# 18272114995           0                 0                  0
# 18272149229           0                 0                  0
# 18271978338           0                 0                  0
#
#              fourth_sub_grinded_value
# 14111400433                         7
# 16026596194                         7
# 28386629404                         0
# 29119359657                         0
# 29012261537                         0
# ...                               ...
# 20430727030                         0
# 18234665295                         0
# 18272114995                         0
# 18272149229                         0
# 18271978338                         0
#
# [1413 rows x 29 columns]

# %% [markdown]
# # On supprime toute rune inférieure au level 11

# %%
data = data[data['level'] > 11]
data = data[data['stars'] > 5]

# %% [markdown]
# # Map

# %%
set = {1:"Energy", 2:"Guard", 3:"Swift", 4:"Blade", 5:"Rage", 6:"Focus", 7:"Endure", 8:"Fatal", 10:"Despair", 11:"Vampire", 13:"Violent",
        14:"Nemesis", 15:"Will", 16:"Shield", 17:"Revenge", 18:"Destroy", 19:"Fight", 20:"Determination", 21:"Enhance", 22:"Accuracy", 23:"Tolerance", 99:"Immemorial"}

data['rune_set'] = data['rune_set'].map(set)
data
# Out:
#             rune_set  rune_slot  rune_equiped  stars  level  efficiency  \
# 14111400433   Energy          2             0      6     15           0
# 16026596194   Energy          2             0      6     15           0
# 28386629404   Energy          2             0      6     15           0
# 29119359657   Energy          2             0      6     15           0
# 29012261537   Energy          3             0      6     15           0
# ...              ...        ...           ...    ...    ...         ...
# 22149241043  Violent          4   11442691344      6     15           0
# 24992956338  Violent          5   11442691344      6     12           0
# 21929836914  Violent          6   11442691344      6     15           0
# 15878878044    Fight          6    3099821118      6     15           0
# 25482187783    Fight          1   12335448357      6     12           0
#
#              max_efficiency  max_efficiency_reachable  gain  main_type  ...  \
# 14111400433               0                         0     0          8  ...
# 16026596194               0                         0     0          8  ...
# 28386629404               0                         0     0          8  ...
# 29119359657               0                         0     0          8  ...
# 29012261537               0                         0     0          5  ...
# ...                     ...                       ...   ...        ...  ...
# 22149241043               0                         0     0          2  ...
# 24992956338               0                         0     0          1  ...
# 21929836914               0                         0     0          2  ...
# 15878878044               0                         0     0          2  ...
# 25482187783               0                         0     0          3  ...
#
#              second_gemme_bool  second_sub_grinded_value  third_sub  \
# 14111400433                  0                         0         10
# 16026596194                  0                         0         11
# 28386629404                  0                         5          6
# 29119359657                  0                         6          4
# 29012261537                  0                         3          6
# ...                        ...                       ...        ...
# 22149241043                  0                         4          6
# 24992956338                  0                         0          9
# 21929836914                  0                         0         12
# 15878878044                  0                         3          6
# 25482187783                  0                         0         12
#
#              third_sub_value  third_gemme_bool  third_sub_grinded_value  \
# 14111400433               18                 0                        0
# 16026596194               10                 1                        0
# 28386629404                8                 1                        6
# 29119359657               12                 0                        6
# 29012261537                6                 0                        6
# ...                      ...               ...                      ...
# 22149241043                8                 0                        6
# 24992956338               10                 0                        0
# 21929836914               26                 0                        0
# 15878878044                8                 1                        7
# 25482187783               16                 0                        0
#
#              fourth_sub  fourth_sub_value  fourth_gemme_bool  \
# 14111400433           4                 5                  1
# 16026596194           6                 6                  0
# 28386629404          11                13                  0
# 29119359657           9                 6                  0
# 29012261537          11                 7                  0
# ...                 ...               ...                ...
# 22149241043           9                10                  0
# 24992956338           4                14                  0
# 21929836914          11                 7                  0
# 15878878044           9                 6                  0
# 25482187783          10                 7                  0
#
#              fourth_sub_grinded_value
# 14111400433                         7
# 16026596194                         7
# 28386629404                         0
# 29119359657                         0
# 29012261537                         0
# ...                               ...
# 22149241043                         0
# 24992956338                         0
# 21929836914                         0
# 15878878044                         0
# 25482187783                         0
#
# [1350 rows x 29 columns]

# %% [markdown]
# # Efficiency

# %%
sub = {1: (375 * 5) * 2, 
       2: 8 * 5, 
       3: (20 * 5) * 2, 
       4: 8 * 5, 
       5:( 20 * 5) * 1, 
       6: 8 * 5, 
       8: 6 * 5, 
       9: 6 * 5, 
       10: 7 * 5, 
       11: 8 * 5, 
       12: 8 * 5}
    # sub_type == 1:  # PV FLAT
    #     max_value = (375 * 5) * 2
    # if sub_type == 2:  # PV %
    #     max_value = 8 * 5
    # if sub_type == 3:  # ATQ FLAT
    #     max_value = (20 * 5) * 2
    # if sub_type == 4:  # ATQ %
    #     max_value = 8 * 5
    # if sub_type == 5:  # DEF FLAT
    #     max_value = (20 * 5) * 2
    # if sub_type == 6:  # DEF %
    #     max_value = 8 * 5
    # if sub_type == 8:  # SPD
    #     max_value = 6 * 5
    # if sub_type == 9:  # CRIT
    #     max_value = 6 * 5
    # if sub_type == 10:  # DCC
    #     max_value = 7 * 5
    # if sub_type == 11:  # RES
    #     max_value = 8 * 5
    # if sub_type == 12:  # ACC
    #     max_value = 8 * 5

    # return max_value

# Value max :
data['first_sub_value_max'] = data['first_sub'].map(sub)
data['second_sub_value_max'] = data['second_sub'].map(sub)
data['third_sub_value_max'] = data['third_sub'].map(sub)
data['fourth_sub_value_max'] = data['fourth_sub'].map(sub)
data['innate_value_max'] = data['innate_type'].replace(sub)


# Value stats de base + meule

data['first_sub_value_total'] = (data['first_sub_value'] + data['first_sub_grinded_value'])
data['second_sub_value_total'] = (data['second_sub_value'] + data['second_sub_grinded_value'])
data['third_sub_value_total'] = (data['third_sub_value'] + data['third_sub_grinded_value'])
data['fourth_sub_value_total'] = (data['fourth_sub_value'] + data['fourth_sub_grinded_value'])

data['efficiency'] = np.where(data['innate_type'] != 0, round(((1+data['innate_value'] / data['innate_value_max'] + data['first_sub_value_total'] / data['first_sub_value_max'] + data['second_sub_value_total'] / data['second_sub_value_max'] + data['third_sub_value_total'] / data['third_sub_value_max'] + data['fourth_sub_value_total'] / data['fourth_sub_value_max']) / 2.8)*100,2),
                              round(((1 + data['first_sub_value_total'] / data['first_sub_value_max'] + data['second_sub_value_total'] / data['second_sub_value_max'] + data['third_sub_value_total'] / data['third_sub_value_max'] + data['fourth_sub_value_total'] / data['fourth_sub_value_max']) / 2.8)*100,2))

# %%
sub_max_lgd = {1:550, 2:10, 3:30, 4:10, 5:30, 6:10, 8:5}
sub_max_heroique = {1:450, 2:7, 3:22, 4:7, 5:22, 6:7, 8:4}

sub = {1: (375 * 5) * 2, 
       2: 8 * 5, 
       3: (20 * 5) * 2, 
       4: 8 * 5, 
       5:( 20 * 5) * 1, 
       6: 8 * 5, 
       8: 6 * 5, 
       9: 6 * 5, 
       10: 7 * 5, 
       11: 8 * 5, 
       12: 8 * 5}

# Certaines stats ne sont pas meulables. On remplace donc le potentiel de meule par 0

dict = {'first_grind_value_max' : 'first_sub', 'second_grind_value_max' : 'second_sub', 'third_grind_value_max' : 'third_sub', 'fourth_grind_value_max' : 'fourth_sub'}

for key, value in dict.items():
       data[key + '_lgd'] = data[value].replace(sub_max_lgd)
       data[key + '_hero'] = data[value].replace(sub_max_heroique)
       
       # Certaines stats ne sont pas meulables. On remplace donc le potentiel de meule par 0
       
       data[key + "_lgd"] = np.where(data[value] > 8, 0,  data[key + "_lgd"])
       data[key + "_hero"] = np.where(data[value] > 8, 0, data[key + "_hero"]) 


# Value stats de base + meule (max)

data['first_sub_value_total_max_lgd'] = (data['first_sub_value'] + data['first_grind_value_max_lgd'])
data['second_sub_value_total_max_lgd'] = (data['second_sub_value'] + data['second_grind_value_max_lgd'])
data['third_sub_value_total_max_lgd'] = (data['third_sub_value'] + data['third_grind_value_max_lgd'])
data['fourth_sub_value_total_max_lgd'] = (data['fourth_sub_value'] + data['fourth_grind_value_max_lgd'])

data['first_sub_value_total_max_hero'] = (data['first_sub_value'] + data['first_grind_value_max_hero'])
data['second_sub_value_total_max_hero'] = (data['second_sub_value'] + data['second_grind_value_max_hero'])
data['third_sub_value_total_max_hero'] = (data['third_sub_value'] + data['third_grind_value_max_hero'])
data['fourth_sub_value_total_max_hero'] = (data['fourth_sub_value'] + data['fourth_grind_value_max_hero'])

# %%
data['efficiency_max_lgd'] = np.where(data['innate_type'] != 0, round(((1+data['innate_value'] / data['innate_value_max'] + data['first_sub_value_total_max_lgd'] / data['first_sub_value_max'] + data['second_sub_value_total_max_lgd'] / data['second_sub_value_max'] + data['third_sub_value_total_max_lgd'] / data['third_sub_value_max'] + data['fourth_sub_value_total_max_lgd'] / data['fourth_sub_value_max']) / 2.8)*100,2),
                              round(((1 + data['first_sub_value_total_max_lgd'] / data['first_sub_value_max'] + data['second_sub_value_total_max_lgd'] / data['second_sub_value_max'] + data['third_sub_value_total_max_lgd'] / data['third_sub_value_max'] + data['fourth_sub_value_total_max_lgd'] / data['fourth_sub_value_max']) / 2.8)*100,2))

data['efficiency_max_hero'] = np.where(data['innate_type'] != 0, round(((1+data['innate_value'] / data['innate_value_max'] + data['first_sub_value_total_max_hero'] / data['first_sub_value_max'] + data['second_sub_value_total_max_hero'] / data['second_sub_value_max'] + data['third_sub_value_total_max_hero'] / data['third_sub_value_max'] + data['fourth_sub_value_total_max_hero'] / data['fourth_sub_value_max']) / 2.8)*100,2),
                              round(((1 + data['first_sub_value_total_max_hero'] / data['first_sub_value_max'] + data['second_sub_value_total_max_hero'] / data['second_sub_value_max'] + data['third_sub_value_total_max_hero'] / data['third_sub_value_max'] + data['fourth_sub_value_total_max_hero'] / data['fourth_sub_value_max']) / 2.8)*100,2))

# %%
data['potentiel_max'] = data['efficiency_max_lgd'] - data['efficiency']

# %%
data.loc[22149241043]
# Out:
# rune_set                               Violent
# rune_slot                                    4
# rune_equiped                       11442691344
# stars                                        6
# level                                       15
# efficiency                               94.81
# max_efficiency                               0
# max_efficiency_reachable                     0
# gain                                         0
# main_type                                    2
# main_value                                  63
# innate_type                                  0
# innate_value                                 0
# first_sub                                   10
# first_sub_value                             13
# first_gemme_bool                             0
# first_sub_grinded_value                      0
# second_sub                                   8
# second_sub_value                            14
# second_gemme_bool                            0
# second_sub_grinded_value                     4
# third_sub                                    6
# third_sub_value                              8
# third_gemme_bool                             0
# third_sub_grinded_value                      6
# fourth_sub                                   9
# fourth_sub_value                            10
# fourth_gemme_bool                            0
# fourth_sub_grinded_value                     0
# first_sub_value_max                         35
# second_sub_value_max                        30
# third_sub_value_max                         40
# fourth_sub_value_max                        30
# innate_value_max                             0
# first_sub_value_total                       13
# second_sub_value_total                      18
# third_sub_value_total                       14
# fourth_sub_value_total                      10
# first_grind_value_max_lgd                    0
# first_grind_value_max_hero                   0
# second_grind_value_max_lgd                   5
# second_grind_value_max_hero                  4
# third_grind_value_max_lgd                   10
# third_grind_value_max_hero                   7
# fourth_grind_value_max_lgd                   0
# fourth_grind_value_max_hero                  0
# first_sub_value_total_max_lgd               13
# second_sub_value_total_max_lgd              19
# third_sub_value_total_max_lgd               18
# fourth_sub_value_total_max_lgd              10
# first_sub_value_total_max_hero              13
# second_sub_value_total_max_hero             18
# third_sub_value_total_max_hero              15
# fourth_sub_value_total_max_hero             10
# efficiency_max_lgd                       99.57
# efficiency_max_hero                      95.71
# potentiel_max                             4.76
# Name: 22149241043, dtype: object

# %% [markdown]
# # On supprime les variables inutiles

# %%
data.drop(['max_efficiency', 'max_efficiency_reachable', 'gain'], axis=1, inplace=True)

# %% [markdown]
# # Map
# ## Propriété
# Plus simple ici qu'avant

# %%
property = {0:'Aucun', 
            1:'HP', 
            2:'HP%', 
            3:'ATQ', 
            4:'ATQ%', 
            5:'DEF', 
            6:'DEF%', 
            8:"SPD", 
            9:'CRIT', 
            10:'DCC', 
            11:'RES', 
            12:'ACC'}

for c in ['innate_type', 'first_sub', 'second_sub', 'third_sub', 'fourth_sub', 'main_type']:
    data[c] = data[c].map(property)

# %% [markdown]
# ## Monstres

# %%
data_mobs = pd.DataFrame.from_dict(data_json, orient="index").transpose()

# %%
data_mobs = data_mobs['unit_list']

# %%
# On va boucler et retenir ce qui nous intéresse..
list_mobs = []
data_mobs[0]
for monstre in data_mobs[0]:
    unit = monstre['unit_id']
    master_id = monstre['unit_master_id']
    list_mobs.append([unit, master_id])
    
# On met ça en dataframe    
df_mobs = pd.DataFrame(list_mobs, columns=['id_unit', 'id_monstre'])

# %%
df_mobs
# Out:
#          id_unit  id_monstre
# 0     1943672600       19411
# 1     4612870451       16611
# 2     6917359809       22011
# 3     6960500803       19211
# 4     6991785178       16111
# ..           ...         ...
# 303  13200364163       18204
# 304  13561635818       12903
# 305  13561719696       12903
# 306  10243398628       12902
# 307  13297684654       18205
#
# [308 rows x 2 columns]

# %% [markdown]
# Maintenant, on a besoin d'identifier les id.
# Pour cela, on va utiliser l'api de swarfarm

# %%
import requests


def swarfarm_monstres():

    url = "https://swarfarm.com/api/v2/monsters/?page=1"
    r = requests.get(url=url)
    data = r.json()
    df = pd.DataFrame(data)


    for i in range(2,21):
        url = f"https://swarfarm.com/api/v2/monsters/?page={i}"
        r = requests.get(url=url)
        data = r.json()
        df2 = pd.DataFrame(data)
        df = pd.concat([df, df2])
        
        
    # on extrait les variables du dict dans la colonne ['results'] et on supprime ce qui m'intéresse pas
    df = extraire_variables_imbriquees(df, 'results')
    df.drop(['next', 'previous'], axis=1, inplace=True)
    # On garde ce qui nous intéresse
    df_mobs_swarfarm = df[['id', 'url', 'com2us_id', 'family_id', 'name']]

    df_mobs_swarfarm.to_excel('swarfarm.xlsx', index=False)

# %%
# swarfarm_monstres() # à activer/désactiver pour maj 
swarfarm = pd.read_excel('swarfarm.xlsx')
swarfarm
# Out:
#         id                                         url  com2us_id  family_id  \
# 0        1     https://swarfarm.com/api/v2/monsters/1/      12302      12300
# 1        2     https://swarfarm.com/api/v2/monsters/2/      12702      12700
# 2        3     https://swarfarm.com/api/v2/monsters/3/      13002      13000
# 3        4     https://swarfarm.com/api/v2/monsters/4/      12902      12900
# 4        5     https://swarfarm.com/api/v2/monsters/5/      12402      12400
# ...    ...                                         ...        ...        ...
# 1941  1957  https://swarfarm.com/api/v2/monsters/1957/      26011      26000
# 1942  1958  https://swarfarm.com/api/v2/monsters/1958/      26012      26000
# 1943  1959  https://swarfarm.com/api/v2/monsters/1959/      26013      26000
# 1944  1960  https://swarfarm.com/api/v2/monsters/1960/      26014      26000
# 1945  1961  https://swarfarm.com/api/v2/monsters/1961/      26015      26000
#
#                name
# 0     Forest Keeper
# 1             Ghost
# 2       Horned Frog
# 3            Mimick
# 4          Mushroom
# ...             ...
# 1941         Birman
# 1942           Manx
# 1943       Nebelung
# 1944        Siamese
# 1945         Bombay
#
# [1946 rows x 5 columns]

# %%
swarfarm = swarfarm[['com2us_id', 'name']].set_index('com2us_id')
df_mobs['name_monstre'] = df_mobs['id_monstre'].map(swarfarm.to_dict(orient="dict")['name'])

# %%
df_mobs
# Out:
#          id_unit  id_monstre   name_monstre
# 0     1943672600       19411        Galleon
# 1     4612870451       16611           Chow
# 2     6917359809       22011        Sabrina
# 3     6960500803       19211       Theomars
# 4     6991785178       16111         Anavel
# ..           ...         ...            ...
# 303  13200364163       18204  King Angelmon
# 304  13561635818       12903         Mimick
# 305  13561719696       12903         Mimick
# 306  10243398628       12902         Mimick
# 307  13297684654       18205  King Angelmon
#
# [308 rows x 3 columns]

# %% [markdown]
# On peut faire le mapping...

# %%
df_mobs = df_mobs[['id_unit', 'name_monstre']].set_index('id_unit')

# %%
data['rune_equiped'] = data['rune_equiped'].replace(df_mobs.to_dict(orient="dict")['name_monstre'])

# %% [markdown]
# # Indicateurs
# ## Runes +15

# %%
data['indicateurs_level'] = (data['level'] == 15).astype('int')

# %% [markdown]
# # Amélioration des Grind

# %%
dict = {'amelioration_first_grind' : ['first_sub_grinded_value', 'first_grind_value'],
        'amelioration_second_grind' : ['second_sub_grinded_value', 'second_grind_value'],
        'amelioration_third_grind' : ['third_sub_grinded_value', 'third_grind_value'],
        'amelioration_fourth_grind' : ['fourth_sub_grinded_value', 'fourth_grind_value']}

for key, value in dict.items():
    # Améliorable ?
    data[key + '_lgd_value'] = data[value[1] + '_max_lgd'] - data[value[0]]
    data[key + '_hero_value'] = data[value[1] + '_max_hero'] - data[value[0]]
    # Améliorable ?
    data[key + '_lgd_ameliorable?'] = (data[key + '_lgd_value'] > 0).astype('int')
    data[key + '_hero_ameliorable?'] = (data[key + '_hero_value'] > 0).astype('int')

# %% [markdown]
# # Commentaires

# %%
# Level
data['Commentaires'] = np.where(data['level'] != 15, "A monter +15 \n", "")
data['Grind_lgd'] = ""
data['Grind_hero'] = ""


dict = {'amelioration_first_grind' : 'first_sub',
        'amelioration_second_grind' : 'second_sub',
        'amelioration_third_grind' : 'third_sub',
        'amelioration_fourth_grind' : 'fourth_sub'}

for key, value in dict.items():
    nom = key + "_lgd_value"
    data['Grind_lgd'] = np.where(data[key + '_lgd_ameliorable?'] == 1, data['Grind_lgd'] +  data[value] + "(" + data[nom].astype('str') + ") \n", data['Grind_lgd'])
    
    nom = key + "_hero_value"
    data['Grind_hero'] = np.where(data[key + '_hero_ameliorable?'] == 1, data['Grind_hero'] +  data[value] + "(" + data[nom].astype('str') + ") \n", data['Grind_hero'])

# %% [markdown]
# # Clean du xl

# %%
data.drop(['stars', 'level'], axis=1, inplace=True)

data_short = data[['rune_set', 'rune_slot', 'rune_equiped', 'efficiency', 'efficiency_max_hero', 'efficiency_max_lgd', 'potentiel_max', 'Grind_lgd', 'Grind_hero']]

# %% [markdown]
# # Export

# %%
export_excel(data, data_short)

# %% [markdown]
# # Pour le fun

# %%
property = {1:'HP', 
            2:'HP%', 
            3:'ATQ', 
            4:'ATQ%', 
            5:'DEF', 
            6:'DEF%', 
            8:"SPD"}


for propriete in property.values():
    count = data['Grind_hero'].str.count(propriete).sum()
    
    print(f'Il manque {count} heroique pour totalement grind au max la stat {propriete}')
# Out:
# Il manque 539 heroique pour totalement grind au max la stat HP
# Il manque 460 heroique pour totalement grind au max la stat HP%
# Il manque 403 heroique pour totalement grind au max la stat ATQ
# Il manque 336 heroique pour totalement grind au max la stat ATQ%
# Il manque 380 heroique pour totalement grind au max la stat DEF
# Il manque 330 heroique pour totalement grind au max la stat DEF%
# Il manque 501 heroique pour totalement grind au max la stat SPD

# %%
for type_rune in set.values():
    for propriete in property.values():
        data_type_rune = data[data['rune_set'] == type_rune]
        nb_rune = data[data['rune_set'] == type_rune].count().max()
        count = data_type_rune['Grind_hero'].str.count(propriete).sum()
        
        if propriete == "HP":
            print(f'Tu as {nb_rune} runes du set {type_rune}')
        print(f'{type_rune} : Il manque {count} heroique pour totalement grind au max la stat {propriete}')
# Out:
# Tu as 38 runes du set Energy
# Energy : Il manque 7 heroique pour totalement grind au max la stat HP
# Energy : Il manque 7 heroique pour totalement grind au max la stat HP%
# Energy : Il manque 6 heroique pour totalement grind au max la stat ATQ
# Energy : Il manque 6 heroique pour totalement grind au max la stat ATQ%
# Energy : Il manque 13 heroique pour totalement grind au max la stat DEF
# Energy : Il manque 13 heroique pour totalement grind au max la stat DEF%
# Energy : Il manque 5 heroique pour totalement grind au max la stat SPD
# Tu as 43 runes du set Guard
# Guard : Il manque 12 heroique pour totalement grind au max la stat HP
# Guard : Il manque 12 heroique pour totalement grind au max la stat HP%
# Guard : Il manque 6 heroique pour totalement grind au max la stat ATQ
# Guard : Il manque 5 heroique pour totalement grind au max la stat ATQ%
# Guard : Il manque 7 heroique pour totalement grind au max la stat DEF
# Guard : Il manque 5 heroique pour totalement grind au max la stat DEF%
# Guard : Il manque 9 heroique pour totalement grind au max la stat SPD
# Tu as 149 runes du set Swift
# Swift : Il manque 66 heroique pour totalement grind au max la stat HP
# Swift : Il manque 49 heroique pour totalement grind au max la stat HP%
# Swift : Il manque 53 heroique pour totalement grind au max la stat ATQ
# Swift : Il manque 42 heroique pour totalement grind au max la stat ATQ%
# Swift : Il manque 52 heroique pour totalement grind au max la stat DEF
# Swift : Il manque 40 heroique pour totalement grind au max la stat DEF%
# Swift : Il manque 66 heroique pour totalement grind au max la stat SPD
# Tu as 47 runes du set Blade
# Blade : Il manque 12 heroique pour totalement grind au max la stat HP
# Blade : Il manque 11 heroique pour totalement grind au max la stat HP%
# Blade : Il manque 14 heroique pour totalement grind au max la stat ATQ
# Blade : Il manque 14 heroique pour totalement grind au max la stat ATQ%
# Blade : Il manque 7 heroique pour totalement grind au max la stat DEF
# Blade : Il manque 6 heroique pour totalement grind au max la stat DEF%
# Blade : Il manque 13 heroique pour totalement grind au max la stat SPD
# Tu as 56 runes du set Rage
# Rage : Il manque 18 heroique pour totalement grind au max la stat HP
# Rage : Il manque 16 heroique pour totalement grind au max la stat HP%
# Rage : Il manque 13 heroique pour totalement grind au max la stat ATQ
# Rage : Il manque 13 heroique pour totalement grind au max la stat ATQ%
# Rage : Il manque 8 heroique pour totalement grind au max la stat DEF
# Rage : Il manque 7 heroique pour totalement grind au max la stat DEF%
# Rage : Il manque 14 heroique pour totalement grind au max la stat SPD
# Tu as 31 runes du set Focus
# Focus : Il manque 12 heroique pour totalement grind au max la stat HP
# Focus : Il manque 10 heroique pour totalement grind au max la stat HP%
# Focus : Il manque 7 heroique pour totalement grind au max la stat ATQ
# Focus : Il manque 7 heroique pour totalement grind au max la stat ATQ%
# Focus : Il manque 10 heroique pour totalement grind au max la stat DEF
# Focus : Il manque 9 heroique pour totalement grind au max la stat DEF%
# Focus : Il manque 3 heroique pour totalement grind au max la stat SPD
# Tu as 33 runes du set Endure
# Endure : Il manque 11 heroique pour totalement grind au max la stat HP
# Endure : Il manque 11 heroique pour totalement grind au max la stat HP%
# Endure : Il manque 8 heroique pour totalement grind au max la stat ATQ
# Endure : Il manque 8 heroique pour totalement grind au max la stat ATQ%
# Endure : Il manque 9 heroique pour totalement grind au max la stat DEF
# Endure : Il manque 9 heroique pour totalement grind au max la stat DEF%
# Endure : Il manque 2 heroique pour totalement grind au max la stat SPD
# Tu as 56 runes du set Fatal
# Fatal : Il manque 17 heroique pour totalement grind au max la stat HP
# Fatal : Il manque 16 heroique pour totalement grind au max la stat HP%
# Fatal : Il manque 22 heroique pour totalement grind au max la stat ATQ
# Fatal : Il manque 16 heroique pour totalement grind au max la stat ATQ%
# Fatal : Il manque 1 heroique pour totalement grind au max la stat DEF
# Fatal : Il manque 1 heroique pour totalement grind au max la stat DEF%
# Fatal : Il manque 23 heroique pour totalement grind au max la stat SPD
# Tu as 63 runes du set Despair
# Despair : Il manque 21 heroique pour totalement grind au max la stat HP
# Despair : Il manque 19 heroique pour totalement grind au max la stat HP%
# Despair : Il manque 19 heroique pour totalement grind au max la stat ATQ
# Despair : Il manque 17 heroique pour totalement grind au max la stat ATQ%
# Despair : Il manque 25 heroique pour totalement grind au max la stat DEF
# Despair : Il manque 20 heroique pour totalement grind au max la stat DEF%
# Despair : Il manque 11 heroique pour totalement grind au max la stat SPD
# Tu as 59 runes du set Vampire
# Vampire : Il manque 17 heroique pour totalement grind au max la stat HP
# Vampire : Il manque 15 heroique pour totalement grind au max la stat HP%
# Vampire : Il manque 13 heroique pour totalement grind au max la stat ATQ
# Vampire : Il manque 11 heroique pour totalement grind au max la stat ATQ%
# Vampire : Il manque 10 heroique pour totalement grind au max la stat DEF
# Vampire : Il manque 9 heroique pour totalement grind au max la stat DEF%
# Vampire : Il manque 9 heroique pour totalement grind au max la stat SPD
# Tu as 324 runes du set Violent
# Violent : Il manque 165 heroique pour totalement grind au max la stat HP
# Violent : Il manque 141 heroique pour totalement grind au max la stat HP%
# Violent : Il manque 117 heroique pour totalement grind au max la stat ATQ
# Violent : Il manque 95 heroique pour totalement grind au max la stat ATQ%
# Violent : Il manque 109 heroique pour totalement grind au max la stat DEF
# Violent : Il manque 95 heroique pour totalement grind au max la stat DEF%
# Violent : Il manque 188 heroique pour totalement grind au max la stat SPD
# Tu as 62 runes du set Nemesis
# Nemesis : Il manque 31 heroique pour totalement grind au max la stat HP
# Nemesis : Il manque 25 heroique pour totalement grind au max la stat HP%
# Nemesis : Il manque 11 heroique pour totalement grind au max la stat ATQ
# Nemesis : Il manque 9 heroique pour totalement grind au max la stat ATQ%
# Nemesis : Il manque 10 heroique pour totalement grind au max la stat DEF
# Nemesis : Il manque 9 heroique pour totalement grind au max la stat DEF%
# Nemesis : Il manque 17 heroique pour totalement grind au max la stat SPD
# Tu as 167 runes du set Will
# Will : Il manque 62 heroique pour totalement grind au max la stat HP
# Will : Il manque 52 heroique pour totalement grind au max la stat HP%
# Will : Il manque 46 heroique pour totalement grind au max la stat ATQ
# Will : Il manque 34 heroique pour totalement grind au max la stat ATQ%
# Will : Il manque 46 heroique pour totalement grind au max la stat DEF
# Will : Il manque 38 heroique pour totalement grind au max la stat DEF%
# Will : Il manque 74 heroique pour totalement grind au max la stat SPD
# Tu as 74 runes du set Shield
# Shield : Il manque 32 heroique pour totalement grind au max la stat HP
# Shield : Il manque 30 heroique pour totalement grind au max la stat HP%
# Shield : Il manque 23 heroique pour totalement grind au max la stat ATQ
# Shield : Il manque 23 heroique pour totalement grind au max la stat ATQ%
# Shield : Il manque 25 heroique pour totalement grind au max la stat DEF
# Shield : Il manque 24 heroique pour totalement grind au max la stat DEF%
# Shield : Il manque 16 heroique pour totalement grind au max la stat SPD
# Tu as 63 runes du set Revenge
# Revenge : Il manque 19 heroique pour totalement grind au max la stat HP
# Revenge : Il manque 18 heroique pour totalement grind au max la stat HP%
# Revenge : Il manque 19 heroique pour totalement grind au max la stat ATQ
# Revenge : Il manque 17 heroique pour totalement grind au max la stat ATQ%
# Revenge : Il manque 19 heroique pour totalement grind au max la stat DEF
# Revenge : Il manque 19 heroique pour totalement grind au max la stat DEF%
# Revenge : Il manque 21 heroique pour totalement grind au max la stat SPD
# Tu as 62 runes du set Destroy
# Destroy : Il manque 25 heroique pour totalement grind au max la stat HP
# Destroy : Il manque 20 heroique pour totalement grind au max la stat HP%
# Destroy : Il manque 13 heroique pour totalement grind au max la stat ATQ
# Destroy : Il manque 12 heroique pour totalement grind au max la stat ATQ%
# Destroy : Il manque 21 heroique pour totalement grind au max la stat DEF
# Destroy : Il manque 20 heroique pour totalement grind au max la stat DEF%
# Destroy : Il manque 17 heroique pour totalement grind au max la stat SPD
# Tu as 14 runes du set Fight
# Fight : Il manque 9 heroique pour totalement grind au max la stat HP
# Fight : Il manque 6 heroique pour totalement grind au max la stat HP%
# Fight : Il manque 9 heroique pour totalement grind au max la stat ATQ
# Fight : Il manque 6 heroique pour totalement grind au max la stat ATQ%
# Fight : Il manque 3 heroique pour totalement grind au max la stat DEF
# Fight : Il manque 2 heroique pour totalement grind au max la stat DEF%
# Fight : Il manque 9 heroique pour totalement grind au max la stat SPD
# Tu as 2 runes du set Determination
# Determination : Il manque 0 heroique pour totalement grind au max la stat HP
# Determination : Il manque 0 heroique pour totalement grind au max la stat HP%
# Determination : Il manque 1 heroique pour totalement grind au max la stat ATQ
# Determination : Il manque 0 heroique pour totalement grind au max la stat ATQ%
# Determination : Il manque 3 heroique pour totalement grind au max la stat DEF
# Determination : Il manque 2 heroique pour totalement grind au max la stat DEF%
# Determination : Il manque 0 heroique pour totalement grind au max la stat SPD
# Tu as 4 runes du set Enhance
# Enhance : Il manque 2 heroique pour totalement grind au max la stat HP
# Enhance : Il manque 1 heroique pour totalement grind au max la stat HP%
# Enhance : Il manque 3 heroique pour totalement grind au max la stat ATQ
# Enhance : Il manque 1 heroique pour totalement grind au max la stat ATQ%
# Enhance : Il manque 1 heroique pour totalement grind au max la stat DEF
# Enhance : Il manque 1 heroique pour totalement grind au max la stat DEF%
# Enhance : Il manque 3 heroique pour totalement grind au max la stat SPD
# Tu as 2 runes du set Accuracy
# Accuracy : Il manque 1 heroique pour totalement grind au max la stat HP
# Accuracy : Il manque 1 heroique pour totalement grind au max la stat HP%
# Accuracy : Il manque 0 heroique pour totalement grind au max la stat ATQ
# Accuracy : Il manque 0 heroique pour totalement grind au max la stat ATQ%
# Accuracy : Il manque 0 heroique pour totalement grind au max la stat DEF
# Accuracy : Il manque 0 heroique pour totalement grind au max la stat DEF%
# Accuracy : Il manque 1 heroique pour totalement grind au max la stat SPD
# Tu as 1 runes du set Tolerance
# Tolerance : Il manque 0 heroique pour totalement grind au max la stat HP
# Tolerance : Il manque 0 heroique pour totalement grind au max la stat HP%
# Tolerance : Il manque 0 heroique pour totalement grind au max la stat ATQ
# Tolerance : Il manque 0 heroique pour totalement grind au max la stat ATQ%
# Tolerance : Il manque 1 heroique pour totalement grind au max la stat DEF
# Tolerance : Il manque 1 heroique pour totalement grind au max la stat DEF%
# Tolerance : Il manque 0 heroique pour totalement grind au max la stat SPD
# Tu as 0 runes du set Immemorial
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat HP
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat HP%
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat ATQ
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat ATQ%
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat DEF
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat DEF%
# Immemorial : Il manque 0 heroique pour totalement grind au max la stat SPD
